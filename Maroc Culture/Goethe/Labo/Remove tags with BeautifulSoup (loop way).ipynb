# %%
import requests

url = 'https://www.goethe.de/ins/ma/fr/ver.cfm?fuseaction=events.detail&event_id=21661881'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text,'html.parser')

# %%
d = soup.find_all('div',class_='audio-dl-c')

# %%
for i in d:
    i.extract()

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="fr">
# <head>
# <meta charset="utf-8"/>
# <meta content="fr" http-equiv="language"/>
# <link href="https://www.goethe.de/ins/ma/fr/m/ver.cfm" media="only screen and (max-width: 640px)" rel="alternate"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="width=device-width" name="viewport"/>
# <meta content="Forte proximité : art, projets de théâtre, réflexion, confrontation - aperçu de tous les évènements du Goethe-Institut au Maroc.
# " name="description"/> <!-- $$customhtml:metakeywords$$ -->
# <!-- $$customhtml:sharifffunction$$ -->
# <script src="//www.goethe.de/resources/relaunch/js/jquery-1.10.2.min.js"></script>
# <script src="//www.goethe.de/resources/relaunch/js/gi/jquery.gi.top-merged.js"></script>
# <script language="javascript">
#
#
#             function anchorClick(anchorname){
#                 $('html, body').animate({ scrollTop: $(anchorname).offset().top - 25 }, 'slow');
#
# ...
