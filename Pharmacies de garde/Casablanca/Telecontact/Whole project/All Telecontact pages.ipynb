# %% [markdown]
# # Displaying the result of Scraping the 50 pages of results

# %%
import pandas as pd

# %%
df = pd.read_csv('ph_full.csv',delimiter=';',index_col=0)

# %%
df
# Out:
#                          pharmacie  \
# 0                Pharmacie  Oulmès
# 1           Pharmacie  Oum Al Qora
# 2          Pharmacie  Oum El Kheir
# 3          Pharmacie  Oum ElBanine
# 4           Pharmacie  Oum Errabii
# 5          Pharmacie  Oum L'Ghaite
# 6                Pharmacie  Oumnia
# 7               Pharmacie  Oussama
# 8               Pharmacie  Ouzineb
# 9               Pharmacie  Oxygène
# 10             Pharmacie  Panorama
# 11          Pharmacie  Panoramique
# 12              Pharmacie  Paranfa
# 13           Pharmacie  parisienne
# 14              Pharmacie  Pitchou
# 15   Pharmacie  Place Ahmed Mekwar
# 16         Pharmacie  Polyclinique
# 17      Pharmacie  Pont de l'Oasis
# 18            Pharmacie  populaire
# 19                Pharmacie  Alabe
# 20       Pharmacie  AlAhd El Jadid
# 21              Pharmacie  Alahram
# 22           Pharmacie  AlAkhawayn
# 23               Pharmacie  AlAlia
# 24               Pharmacie  AlAmal
# ...

# %%
df.describe()
# Out:
#                  pharmacie                                               lien  \
# count                  979                                                979
# unique                 695                                                695
# top     Pharmacie  Annahda  https://www.telecontact.ma/annonceur/pharmacie...
# freq                     4                                                  4
#
#            access      coordonnee
# count         979             979
# unique        670             650
# top     NO ACCESS  NO COORDINATES
# freq           35              35

# %% [markdown]
# Telecontact says that it has 1230 results for all the pharmacies in Casablanca. But the page results are always random.
# Here we see that despite of the 979 different elements, w can notice that we have many duplicates

# %%
df['pharmacie'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 949    False
# 950    False
# 951    False
# 952    False
# 953    False
# 954    False
# 955    False
# 956    False
# 957    False
# 958    False
# 959     True
# 960     True
# 961     True
# 962     True
# 963     True
# 964     True
# 965     True
# 966    False
# 967    False
# 968    False
# 969    False
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: pharmacie, Length: 979, dtype: bool

# %% [markdown]
# ** Display all the duplicated pharmacies **

# %%
dup = pd.DataFrame()

# %%
dup['pharmacie'] = df['pharmacie']

# %%
dup['is_duplicate'] = df.duplicated()

# %%
redundance = dup[dup['is_duplicate'] == True]

# %%
redundance
# Out:
#                            pharmacie  is_duplicate
# 213                Pharmacie  Smaali          True
# 214                 Pharmacie  Smara          True
# 215                Pharmacie  Smirès          True
# 216               Pharmacie  Snoussi          True
# 217               Pharmacie  Socrate          True
# 218                Pharmacie  Sophia          True
# 268                 Pharmacie  Sevam          True
# 269             Pharmacie  Shahrazad          True
# 270     Pharmacie  Sidi Abderrahmane          True
# 271         Pharmacie  Sidi Elkhadir          True
# 272          Pharmacie  Sidi Maârouf          True
# 273           Pharmacie  Sidi Moumen          True
# 274           Pharmacie  Sidi Othman          True
# 275            Pharmacie  Sidi Soufi          True
# 276             Pharmacie  Sifeddine          True
# 277                 Pharmacie  Siham          True
# 278            Pharmacie  Sijilmassa          True
# ...
