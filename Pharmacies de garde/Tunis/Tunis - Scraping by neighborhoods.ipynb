# %%
import requests

url = 'https://www.med.tn/pharmacie/tunis'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(response.text,'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
results = soup.find('div',class_="resultsxyz")

# %%
results
# Out:
# <div class="resultsxyz" dir="ltr">
# <div class="slider pharmacy-city" style="margin-bottom: 15px;display: none">
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/tunis/bab-bhar" style="margin-right:7px;" title="Pharmacie à Bab Bhar Tunis">Bab Bhar (93)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/tunis/la-marsa" style="margin-right:7px;" title="Pharmacie à La Marsa Tunis">La Marsa (27)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/tunis/le-bardo" style="margin-right:7px;" title="Pharmacie à Le Bardo Tunis">Le Bardo (20)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/tunis/sidi-hassine" style="margin-right:7px;" title="Pharmacie à Sidi Hassine Tunis">Sidi Hassine (17)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/tunis/el-hrairia" style="margin-right:7px;" title="Pharmacie à El Hrairia Tunis">El Hrairia (15)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/tunis/le-kram" style="margin-right:7px;" title="Pharmacie à Le Kram Tunis">Le Kram (13)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/tunis/ain-zaghouan" style="margin-right:7px;" title="Pharmacie à Aîn Zaghouan Tunis">Aîn Zaghouan (8)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/tunis/les-berges-du-lac" style="margin-right:7px;" title="Pharmacie à Les Berges Du Lac Tunis">Les Berges Du Lac (7)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/tunis/laouina" style="margin-right:7px;" title="Pharmacie à L'aouina Tunis">L'aouina (6)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/tunis/el-manar-2" style="margin-right:7px;" title="Pharmacie à El Manar 2 Tunis">El Manar 2 (6)</a>
# </div>
# </div>
# <div class="searchResults-content clearfix">
# <div class="searchResults-itemDoctor" id="e1ada7c9643bcaed619d820052896ad2">
# <div class="searchResults-card card-doctor " data-key="e1ada7c9643bcaed619d820052896ad2" data-lat="" data-lng="">
# <div class="card-doctor-header">
# <div class="card-doctor-picture">
# <a href="https://www.med.tn/pharmacie/tunis/amel-smaoui-ep.-hamdi-402.html" title="Pharmacie AMEL SMAOUI EP. HAMDI"><img alt="Pharmacie AMEL SMAOUI EP. HAMDI" src="img/pharma.png"/>
# </a>
# </div>
# <a href="https://www.med.tn/pharmacie/tunis/amel-smaoui-ep.-hamdi-402.html" title="Pharmacie AMEL SMAOUI EP. HAMDI">
# <div class="card-doctor-info">
# <h2>
# <span class="practitioner-title">Pharmacie de  garde</span>
# <span class="practitioner-name">AMEL SMAOUI EP. HAMDI</span></h2>
# <p class="practitioner-speciality"><strong class="text-success">Ouverte</strong></p>
# <div class="practitioner-address">
# <img alt="Tunisie" src="https://www.med.tn/img/tunisie.svg"/>
# <p>62,avenue Habib Bourguiba La Goulette Tunis                                Tunisie
#
#
#                            </p>
# </div>
# </div></a>
# <div class="card-doctor-button">
# <a class="btn" href="https://www.med.tn/pharmacie/tunis/amel-smaoui-ep.-hamdi-402.html" style="min-width: 140px;">Voir Fiche</a>
# <a class="btn" href="https://www.google.com/maps?saddr&amp;daddr=36.819843,10.306965" style="min-width: 140px;" target="_dir">Itinéraire</a>
# <a class="btn btn-phone" href="tel:+21671735684"><span class="hide-tel">+216.71.735.684</span><span class="view-tel">+216.71.735.684</span></a>
# </div>
# </div>
# </div>
# </div>
# <div class="searchResults-itemDoctor" id="1812838162fa1e129b31616dfe374a67">
# <div class="searchResults-card card-doctor " data-key="1812838162fa1e129b31616dfe374a67" data-lat="" data-lng="">
# <div class="card-doctor-header">
# <div class="card-doctor-picture">
# <a href="https://www.med.tn/pharmacie/tunis/dalila-darghouth-8225.html" title="Pharmacie DALILA DARGHOUTH"><img alt="Pharmacie DALILA DARGHOUTH" src="img/pharma.png"/>
# </a>
# </div>
# <a href="https://www.med.tn/pharmacie/tunis/dalila-darghouth-8225.html" title="Pharmacie DALILA DARGHOUTH">
# <div class="card-doctor-info">
# <h2>
# <span class="practitioner-title">Pharmacie de  garde</span>
# <span class="practitioner-name">DALILA DARGHOUTH</span></h2>
# <p class="practitioner-speciality"><strong class="text-success">Ouverte</strong></p>
# <div class="practitioner-address">
# <img alt="Tunisie" src="https://www.med.tn/img/tunisie.svg"/>
# <p>Avenue Khaled Ibn El Walid Aîn Zaghouan Tunis                                Tunisie
#
#
#                            </p>
# </div>
# </div></a>
# <div class="card-doctor-button">
# <a class="btn" href="https://www.med.tn/pharmacie/tunis/dalila-darghouth-8225.html" style="min-width: 140px;">Voir Fiche</a>
# <a class="btn" href="https://www.google.com/maps?saddr&amp;daddr=36.8617726,10.2767491" style="min-width: 140px;" target="_dir">Itinéraire</a>
# <a class="btn btn-phone" href="tel:+21670736098"><span class="hide-tel">+216.70.736.098</span><span class="view-tel">+216.70.736.098</span></a>
# </div>
# </div>
# </div>
# </div>
# <div class="searchResults-itemDoctor" id="f2b29b154763c7c51e1090f4bb3911a6">
# <div class="searchResults-card card-doctor " data-key="f2b29b154763c7c51e1090f4bb3911a6" data-lat="" data-lng="">
# <div class="card-doctor-header">
# <div class="card-doctor-picture">
# <a href="https://www.med.tn/pharmacie/tunis/samy-besbes-473.html" title="Pharmacie SAMY BESBES"><img alt="Pharmacie SAMY BESBES" src="img/pharma.png"/>
# </a>
# </div>
# <a href="https://www.med.tn/pharmacie/tunis/samy-besbes-473.html" title="Pharmacie SAMY BESBES">
# <div class="card-doctor-info">
# <h2>
# <span class="practitioner-title">Pharmacie du  jour</span>
# <span class="practitioner-name">SAMY BESBES</span></h2>
# <p class="practitioner-speciality"><strong class="text-success">Ouverte</strong></p>
# <div class="practitioner-address">
# <img alt="Tunisie" src="https://www.med.tn/img/tunisie.svg"/>
# <p>Immeuble Mirmar Business City Centre Urbain Nord Tunis                                Tunisie
#
#
#                            </p>
# </div>
# </div></a>
# <div class="card-doctor-button">
# <a class="btn" href="https://www.med.tn/pharmacie/tunis/samy-besbes-473.html" style="min-width: 140px;">Voir Fiche</a>
# <a class="btn" href="https://www.google.com/maps?saddr&amp;daddr=36.8451665,10.19671059999996" style="min-width: 140px;" target="_dir">Itinéraire</a>
# <a class="btn btn-phone" href="tel:+21670033004"><span class="hide-tel">+216.70.033.004</span><span class="view-tel">+216.70.033.004</span></a>
# </div>
# </div>
# </div>
# </div>
# <div class="searchResults-itemDoctor" id="d0109c90f0cb0dda679a2c7d1beb48db">
# <div class="searchResults-card card-doctor " data-key="d0109c90f0cb0dda679a2c7d1beb48db" data-lat="" data-lng="">
# <div class="card-doctor-header">
# <div class="card-doctor-picture">
# <a href="https://www.med.tn/pharmacie/tunis/mohamed
src="img/pharma.png"/>
# </a>
# </div>
# <a href="https://www.med.tn/pharmacie/tunis/aida-louzir-ep.-ben-messaoud-628.html" title="Pharmacie AIDA LOUZIR EP. BEN MESSAOUD">
# <div class="card-doctor-info">
# <h2>
# <span class="practitioner-title">Pharmacie du  jour</span>
# <span class="practitioner-name">AIDA LOUZIR EP. BEN MESSAOUD</span></h2>
# <p class="practitioner-speciality"><strong class="text-success">Ouverte</strong></p>
# <div class="practitioner-address">
# <img alt="Tunisie" src="https://www.med.tn/img/tunisie.svg"/>
# <p>C.Comm.Carrefour    Route de la Marsa La Marsa Tunis                                Tunisie
#
#
#                            </p>
# </div>
# </div></a>
# <div class="card-doctor-button">
# <a class="btn" href="https://www.med.tn/pharmacie/tunis/aida-louzir-ep.-ben-messaoud-628.html" style="min-width: 140px;">Voir Fiche</a>
# <a class="btn" href="https://www.google.com/maps?saddr&amp;daddr=36.865108,10.294639" style="min-width: 140px;" target="_dir">Itinéraire</a>
# <a class="btn btn-phone" href="tel:+21671779075"><span class="hide-tel">+216.71.779.075</span><span class="view-tel">+216.71.779.075</span></a>
# </div>
# </div>
# </div>
# </div>
# <div class="searchResults-itemDoctor" id="8e9be78ece8abc3332e4820f6ccb3ef9">
# <div class="searchResults-card card-doctor " data-key="8e9be78ece8abc3332e4820f6ccb3ef9" data-lat="" data-lng="">
# <div class="card-doctor-header">
# <div class="card-doctor-picture">
# <a href="https://www.med.tn/pharmacie/tunis/tarek-ben-cheikh-boubaker-1518.html" title="Pharmacie TAREK BEN CHEIKH BOUBAKER"><img alt="Pharmacie TAREK BEN CHEIKH BOUBAKER" src="img/pharma.png"/>
# </a>
# </div>
# <a href="https://www.med.tn/pharmacie/tunis/tarek-ben-cheikh-boubaker-1518.html" title="Pharmacie TAREK BEN CHEIKH BOUBAKER">
# <div class="card-doctor-info">
# <h2>
# <span class="practitioner-title">Pharmacie du  jour</span>
# <span class="practitioner-name">TAREK BEN CHEIKH BOUBAKER</span></h2>
# <p class="practitioner-speciality"><strong class="text-success">Ouverte</strong></p>
# <div class="practitioner-address">
# <img alt="Tunisie" src="https://www.med.tn/img/tunisie.svg"/>
# <p>Angle Rue du Lac Ladoga et Rue du Lac Turkana Les Berges Du Lac Tunis                                Tunisie
#
#
#                            </p>
# </div>
# </div></a>
# <div class="card-doctor-button">
# <a class="btn" href="https://www.med.tn/pharmacie/tunis/tarek-ben-cheikh-boubaker-1518.html" style="min-width: 140px;">Voir Fiche</a>
# <a class="btn" href="https://www.google.com/maps?saddr&amp;daddr=36.8403905,10.2516005" style="min-width: 140px;" target="_dir">Itinéraire</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>

# %%
slider = results.find_all('a',class_="btn btn-default btn-sm")

# %%
len(slider)
# Out:
# 10

# %%
liens_quartiers = []
for i in slider:
    print(i['href'])
    liens_quartiers.append(i['href'])
# Out:
# https://www.med.tn/pharmacie/tunis/bab-bhar
# https://www.med.tn/pharmacie/tunis/la-marsa
# https://www.med.tn/pharmacie/tunis/le-bardo
# https://www.med.tn/pharmacie/tunis/sidi-hassine
# https://www.med.tn/pharmacie/tunis/el-hrairia
# https://www.med.tn/pharmacie/tunis/le-kram
# https://www.med.tn/pharmacie/tunis/ain-zaghouan
# https://www.med.tn/pharmacie/tunis/les-berges-du-lac
# https://www.med.tn/pharmacie/tunis/laouina
# https://www.med.tn/pharmacie/tunis/el-manar-2

# %%
liens_quartiers
# Out:
# ['https://www.med.tn/pharmacie/tunis/bab-bhar',
#  'https://www.med.tn/pharmacie/tunis/la-marsa',
#  'https://www.med.tn/pharmacie/tunis/le-bardo',
#  'https://www.med.tn/pharmacie/tunis/sidi-hassine',
#  'https://www.med.tn/pharmacie/tunis/el-hrairia',
#  'https://www.med.tn/pharmacie/tunis/le-kram',
#  'https://www.med.tn/pharmacie/tunis/ain-zaghouan',
#  'https://www.med.tn/pharmacie/tunis/les-berges-du-lac',
#  'https://www.med.tn/pharmacie/tunis/laouina',
#  'https://www.med.tn/pharmacie/tunis/el-manar-2']

# %% [markdown]
# ## Scraping link by link

# %%
from time import time
from time import sleep
from random import randint

# %%
start_time = time()
requests = 0

# %%
from requests import get

# %%
noms = []

for i in liens_quartiers:
    print(i)
    
    response = get(i)
    
    timer = randint(8,15)
    #pause de loop
    print(timer)
    sleep(timer)
    
    #Scraping the links
    soup = BeautifulSoup(response.text,'html.parser')
    
    results = soup.find_all('div',class_="searchResults-itemDoctor")
    
    for i in results:
        print(i.find('span',class_='practitioner-name').text)
        noms.append((i.find('span',class_='practitioner-name').text).lower())
    
    
    
    
    
print(" *** Done ***")
# Out:
# https://www.med.tn/pharmacie/tunis/bab-bhar
# SAMIA JAZI
# https://www.med.tn/pharmacie/tunis/laouina
# 13
# NAJET HAMOUDA
# MONIA KLIBI EP. DJELLOULI
# KAREM GHATTAS
# Jallel eddine Baklouti
# SAMIA BELHEDI
# NAJOUA KASTALLI
# https://www.med.tn/pharmacie/tunis/el-manar-2
# 9
# NEDRA MILADI EP. M''RABET
# KHALED SASSI
# CHEDLY EL FAZAA
# SOUAD ACHOUR
# TARAK KARRAY
# MOURAD ZOUARI

# %%
noms
# Out:
# ['mohamed chedli amous',
#  'taoufik khabthani',
#  'mohamed moncef bel cadhi',
#  'taoufik belhadj ammar',
#  'mohamed ali abid',
#  'faiza ben abderrahman',
#  'bechir elouati',
#  'habib ben yahia',
#  'mohamed kessentini',
#  'bechir habib',
#  'latifa benzarti ep. chayata',
#  'ali farhat',
#  'imene ezzine ep. ghanouchi',
#  'hella rokbi ep. ben maamer',
#  'donia mellouli ep. mabrouk',
#  'manoubi darghouth',
#  'lobna bouaziz',
#  'aida louzir ep. ben messaoud',
#  'sami ben fadhloun',
#  'najet sabbagh ep. ben jemia',
#  'hatem garram',
#  "mohamed tabrizi m''barki",
#  'dalenda el ferktaji  ep. mouldi rmeki',
#  'faycal azzouz',
#  'majed turki',
#  'zeineb nefzi',
#  'malika esghir ep. ben abdallah',
#  'nabila hamdani ep. skhiri',
#  'lamia largueche ep. amara',
#  'slaheddine hajam',
#  'abdelmajid jarray',
#  'monia hasnaoui',
#  'nabiha ben tanfous',
#  'rim lakhoua',
#  'assia bekdache',
#  'mohamed ghazi kechaou',
#  'mehrez el mili',
#  'latifa ben mansour ep. hicheri',
#  'zeineb andolsi ep. chiboub',
#  'dalel jerbi ep. jemli wahiba',
#  'rached chichti',
#  'ali fakhfakh',
#  'dorsaf ben slimane ep. mchirgui',
#  'lilia ben mahmoud ep. ben hamza',
#  'badria triki ep. ksouri',
#  'rim elloumi ep. maalej',
#  'dalenda bennour',
#  'mohamed adel chaabouni',
#  'habiba grina',
#  'fettah youssefi',
#  'aicha lazaar ep. lazrag',
#  'mohamed cherif darmoul',
#  'houda gharbi ep. tabka',
#  'khaled snoussi',
#  'mohamed mondher ennaifer',
#  'habib zouiten',
#  'sonia mellouli ep. ghariani',
#  'amel kheder ep. parriaux',
#  'lotfi najar',
#  'amel messadi ep. bey',
#  'dalila darghouth',
#  'olfa znazen',
#  'ameni khedhri ouanes',
#  'ines harzallah ep. louati',
#  'maha bousnina ep. janfaoui',
#  'zied ammar',
#  'helali kheder',
#  'nadra ben brahim ep. oueslati',
#  'mohamed azzouz',
#  'myriam kharraz ep chelbi',
#  'moufida bouzouita ep. ghanem',
#  'camilia abbassi bhouri',
#  'tarek ben cheikh boubaker',
#  'hedia chenchah ep. ben hamza',
#  'samia jazi',
#  'najet hamouda',
#  'monia klibi ep. djellouli',
#  'karem ghattas',
#  'jallel eddine baklouti',
#  'samia belhedi',
#  'najoua kastalli',
#  "nedra miladi ep. m''rabet",
#  'khaled sassi',
#  'chedly el fazaa',
#  'souad achour',
#  'tarak karray',
#  'mourad zouari']
