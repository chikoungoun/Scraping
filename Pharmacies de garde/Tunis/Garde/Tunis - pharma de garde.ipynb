# %% [markdown]
# # Pharmacie de Garde

# %%
import requests

url = 'https://www.med.tn/pharmacie/garde/tunis'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(response.text,'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
results = soup.find('div',class_="resultsxyz")

# %%
results
# Out:
# <div class="resultsxyz" dir="ltr">
# <div class="slider pharmacy-city" style="margin-bottom: 15px;display: none">
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/garde/tunis/le-bardo" style="margin-right:7px;" title="Pharmacie de Garde à Le Bardo Tunis">Le Bardo (4)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/garde/tunis/sidi-hassine" style="margin-right:7px;" title="Pharmacie de Garde à Sidi Hassine Tunis">Sidi Hassine (4)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/garde/tunis/la-marsa" style="margin-right:7px;" title="Pharmacie de Garde à La Marsa Tunis">La Marsa (4)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/garde/tunis/el-hrairia" style="margin-right:7px;" title="Pharmacie de Garde à El Hrairia Tunis">El Hrairia (3)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/garde/tunis/le-kram" style="margin-right:7px;" title="Pharmacie de Garde à Le Kram Tunis">Le Kram (2)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/garde/tunis/el-ouerdia" style="margin-right:7px;" title="Pharmacie de Garde à El Ouerdia Tunis">El Ouerdia (2)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/garde/tunis/el-manar-1" style="margin-right:7px;" title="Pharmacie de Garde à El Manar 1 Tunis">El Manar 1 (1)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/garde/tunis/les-berges-du-lac-2" style="margin-right:7px;" title="Pharmacie de Garde à Les Berges Du Lac 2 Tunis">Les Berges Du Lac 2 (1)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/garde/tunis/centre-urbain-nord" style="margin-right:7px;" title="Pharmacie de Garde à Centre Urbain Nord Tunis">Centre Urbain Nord (1)</a>
# </div>
# <div>
# <a class="btn btn-default btn-sm" href="https://www.med.tn/pharmacie/garde/tunis/jebel-jelloud" style="margin-right:7px;" title="Pharmacie de Garde à Jebel Jelloud Tunis">Jebel Jelloud (1)</a>
# </div>
# </div>
# <div class="searchResults-content clearfix">
# <div class="searchResults-itemDoctor" id="d7714a72a4dd59f2887b6bf897a2090e">
# <div class="searchResults-card card-doctor " data-key="d7714a72a4dd59f2887b6bf897a2090e" data-lat="" data-lng="">
# <div class="card-doctor-header">
# <div class="card-doctor-picture">
# <a href="https://www.med.tn/pharmacie/tunis/anis-ben-abdallah-1489.html" title="Pharmacie ANIS BEN ABDALLAH"><img alt="Pharmacie ANIS BEN ABDALLAH" src="img/pharma.png"/>
# </a>
# </div>
# <a href="https://www.med.tn/pharmacie/tunis/anis-ben-abdallah-1489.html" title="Pharmacie ANIS BEN ABDALLAH">
# <div class="card-doctor-info">
# <h2>
# <span class="practitioner-title">Pharmacie de  garde</span>
# <span class="practitioner-name">ANIS BEN ABDALLAH</span></h2>
# <p class="practitioner-speciality"><strong class="text-success">Ferme dans 9 min</strong></p>
# <div class="practitioner-address">
# <img alt="Tunisie" src="https://www.med.tn/img/tunisie.svg"/>
# <p>49,Avenue Farhat Hached kram Le Kram Tunis                                Tunisie
#
#
#                            </p>
# </div>
# </div></a>
# <div class="card-doctor-button">
# <a class="btn" href="https://www.med.tn/pharmacie/tunis/anis-ben-abdallah-1489.html" style="min-width: 140px;">Voir Fiche</a>
# <a class="btn" href="https://www.google.com/maps?saddr&amp;daddr=36.840939,10.311541" style="min-width: 140px;" target="_dir">Itinéraire</a>
# <a class="btn btn-phone" href="tel:+21671277904"><span class="hide-tel">+216.71.277.904</span><span class="view-tel">+216.71.277.904</span></a>
# </div>
# </div>
# </div>
# </div>
# <div class="searchResults-itemDoctor" id="2fdbc1b11f84e88b3719c3df665e61ae">
# <div class="searchResults-card card-doctor " data-key="2fdbc1b11f84e88b3719c3df665e61ae" data-lat="" data-lng="">
# <div class="card-doctor-header">
# <div class="card-doctor-picture">
# <a href="https://www.med.tn/pharmacie/tunis/salima-ghorbel-ep.-lazrak-1332.html" title="Pharmacie SALIMA GHORBEL EP. LAZRAK"><img alt="Pharmacie SALIMA GHORBEL EP. LAZRAK" src="img/pharma.png"/>
# </a>
# </div>
# <a href="https://www.med.tn/pharmacie/tunis/salima-ghorbel-ep.-lazrak-1332.html" title="Pharmacie SALIMA GHORBEL EP. LAZRAK">
# <div class="card-doctor-info">
# <h2>
# <span class="practitioner-title">Pharmacie de  garde</span>
# <span class="practitioner-name">SALIMA GHORBEL EP. LAZRAK</span></h2>
# <p class="practitioner-speciality"><strong class="text-success">Ferme dans 9 min</strong></p>
# <div class="practitioner-address">
# <img alt="Tunisie" src="https://www.med.tn/img/tunisie.svg"/>
# <p>28,rue 8714 Cite Olympique Cite El Khadhra Tunis                                Tunisie
#
#
#                            </p>
# </div>
# </div></a>
# <div class="card-doctor-button">
# <a class="btn" href="https://www.med.tn/pharmacie/tunis/salima-ghorbel-ep.-lazrak-1332.html" style="min-width: 140px;">Voir Fiche</a>
# <a class="btn" href="https://www.google.com/maps?saddr&amp;daddr=36.836231,10.193851" style="min-width: 140px;" target="_dir">Itinéraire</a>
# <a class="btn btn-phone" href="tel:+21671894135"><span class="hide-tel">+216.71.894.135</span><span class="view-tel">+216.71.894.135</span></a>
# </div>
# </div>
# </div>
# </div>
# <div class="searchResults-itemDoctor" id="ca60f155116201aab0072420d0f7b754">
# <div class="searchResults-card card-doctor " data-key="ca60f155116201aab0072420d0f7b754" data-lat="" data-lng="">
# <div class="card-doctor-header">
# <div class="card-doctor-picture">
# <a href="https://www.med.tn/pharmacie/tunis/bassem-miled-1295.html" title="Pharmacie BASSEM MILED"><img alt="Pharmacie BASSEM MILED" src="img/pharma.png"/>
# </a>
# </div>
# <a href="https://www.med.tn/pharmacie/tunis/bassem-miled-1295.html" title="Pharmacie BASSEM MILED">
# <div class="card-doctor-info">
# <h2>
# <span class="practitioner-title">Pharmacie de  garde</span>
# <span class="practitioner-name">BASSEM MILED</span></h2>
# <p class="practitioner-speciality"><strong class="text-success">Ferme dans 9 min</strong></p>
# <div class="practitioner-address">
# <img alt="Tunisie" src="https://www.med.tn/img/tunisie.svg"/>
# <p>
data-lat="" data-lng="">
# <div class="card-doctor-header">
# <div class="card-doctor-picture">
# <a href="https://www.med.tn/pharmacie/tunis/leila-ben-slama-ep.-zouari-287.html" title="Pharmacie LEILA BEN SLAMA EP. ZOUARI"><img alt="Pharmacie LEILA BEN SLAMA EP. ZOUARI" src="img/pharma.png"/>
# </a>
# </div>
# <a href="https://www.med.tn/pharmacie/tunis/leila-ben-slama-ep.-zouari-287.html" title="Pharmacie LEILA BEN SLAMA EP. ZOUARI">
# <div class="card-doctor-info">
# <h2>
# <span class="practitioner-title">Pharmacie de  garde</span>
# <span class="practitioner-name">LEILA BEN SLAMA EP. ZOUARI</span></h2>
# <p class="practitioner-speciality"><strong class="text-success">Ferme dans 9 min</strong></p>
# <div class="practitioner-address">
# <img alt="Tunisie" src="https://www.med.tn/img/tunisie.svg"/>
# <p>60,avenue Taieb M'Hiri La Marsa Tunis                                Tunisie
#
#
#                            </p>
# </div>
# </div></a>
# <div class="card-doctor-button">
# <a class="btn" href="https://www.med.tn/pharmacie/tunis/leila-ben-slama-ep.-zouari-287.html" style="min-width: 140px;">Voir Fiche</a>
# <a class="btn" href="https://www.google.com/maps?saddr&amp;daddr=36.889851,10.321507" style="min-width: 140px;" target="_dir">Itinéraire</a>
# <a class="btn btn-phone" href="tel:+21672225420"><span class="hide-tel">+216.72.225.420</span><span class="view-tel">+216.72.225.420</span></a>
# </div>
# </div>
# </div>
# </div>
# <div class="searchResults-itemDoctor" id="f0491c7fa6586e00c2cecb2ff25d5092">
# <div class="searchResults-card card-doctor " data-key="f0491c7fa6586e00c2cecb2ff25d5092" data-lat="" data-lng="">
# <div class="card-doctor-header">
# <div class="card-doctor-picture">
# <a href="https://www.med.tn/pharmacie/tunis/abdelhamid-chelfouh-68.html" title="Pharmacie ABDELHAMID CHELFOUH"><img alt="Pharmacie ABDELHAMID CHELFOUH" src="img/pharma.png"/>
# </a>
# </div>
# <a href="https://www.med.tn/pharmacie/tunis/abdelhamid-chelfouh-68.html" title="Pharmacie ABDELHAMID CHELFOUH">
# <div class="card-doctor-info">
# <h2>
# <span class="practitioner-title">Pharmacie de  garde</span>
# <span class="practitioner-name">ABDELHAMID CHELFOUH</span></h2>
# <p class="practitioner-speciality"><strong class="text-success">Ferme dans 9 min</strong></p>
# <div class="practitioner-address">
# <img alt="Tunisie" src="https://www.med.tn/img/tunisie.svg"/>
# <p>3, Avenue Roosvelt La Goulette Tunis                                Tunisie
#
#
#                            </p>
# </div>
# </div></a>
# <div class="card-doctor-button">
# <a class="btn" href="https://www.med.tn/pharmacie/tunis/abdelhamid-chelfouh-68.html" style="min-width: 140px;">Voir Fiche</a>
# <a class="btn" href="https://www.google.com/maps?saddr&amp;daddr=36.8163319100532,10.304876894512176" style="min-width: 140px;" target="_dir">Itinéraire</a>
# <a class="btn btn-phone" href="tel:+21671735232"><span class="hide-tel">+216.71.735.232</span><span class="view-tel">+216.71.735.232</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>

# %% [markdown]
# ### Neighborhood links

# %%
slider = results.find_all('a',class_="btn btn-default btn-sm")

# %%
len(slider)
# Out:
# 10

# %%
liens_quartiers = []
for i in slider:
    print(i['href'])
    liens_quartiers.append(i['href'])
# Out:
# https://www.med.tn/pharmacie/garde/tunis/le-bardo
# https://www.med.tn/pharmacie/garde/tunis/sidi-hassine
# https://www.med.tn/pharmacie/garde/tunis/la-marsa
# https://www.med.tn/pharmacie/garde/tunis/el-hrairia
# https://www.med.tn/pharmacie/garde/tunis/le-kram
# https://www.med.tn/pharmacie/garde/tunis/el-ouerdia
# https://www.med.tn/pharmacie/garde/tunis/el-manar-1
# https://www.med.tn/pharmacie/garde/tunis/les-berges-du-lac-2
# https://www.med.tn/pharmacie/garde/tunis/centre-urbain-nord
# https://www.med.tn/pharmacie/garde/tunis/jebel-jelloud

# %%
liens_quartiers
# Out:
# ['https://www.med.tn/pharmacie/garde/tunis/le-bardo',
#  'https://www.med.tn/pharmacie/garde/tunis/sidi-hassine',
#  'https://www.med.tn/pharmacie/garde/tunis/la-marsa',
#  'https://www.med.tn/pharmacie/garde/tunis/el-hrairia',
#  'https://www.med.tn/pharmacie/garde/tunis/le-kram',
#  'https://www.med.tn/pharmacie/garde/tunis/el-ouerdia',
#  'https://www.med.tn/pharmacie/garde/tunis/el-manar-1',
#  'https://www.med.tn/pharmacie/garde/tunis/les-berges-du-lac-2',
#  'https://www.med.tn/pharmacie/garde/tunis/centre-urbain-nord',
#  'https://www.med.tn/pharmacie/garde/tunis/jebel-jelloud']

# %% [markdown]
# ### Neighborhood names

# %%
noms_quartiers = []
for i in slider:
    print(i.text)
    noms_quartiers.append(i.text[:i.text.find('(')].strip())
# Out:
# Le Bardo (4)
# Sidi Hassine (4)
# La Marsa (4)
# El Hrairia (3)
# Le Kram (2)
# El Ouerdia (2)
# El Manar 1 (1)
# Les Berges Du Lac 2 (1)
# Centre Urbain Nord (1)
# Jebel Jelloud (1)

# %%
noms_quartiers
# Out:
# ['Le Bardo',
#  'Sidi Hassine',
#  'La Marsa',
#  'El Hrairia',
#  'Le Kram',
#  'El Ouerdia',
#  'El Manar 1',
#  'Les Berges Du Lac 2',
#  'Centre Urbain Nord',
#  'Jebel Jelloud']

# %% [markdown]
# ### Neighborhood duo

# %%
duo_quartier = []
for i,j in zip(liens_quartiers,noms_quartiers):
    t = (i,j)
    duo_quartier.append(t)

# %%
duo_quartier
# Out:
# [('https://www.med.tn/pharmacie/garde/tunis/le-bardo', 'Le Bardo'),
#  ('https://www.med.tn/pharmacie/garde/tunis/sidi-hassine', 'Sidi Hassine'),
#  ('https://www.med.tn/pharmacie/garde/tunis/la-marsa', 'La Marsa'),
#  ('https://www.med.tn/pharmacie/garde/tunis/el-hrairia', 'El Hrairia'),
#  ('https://www.med.tn/pharmacie/garde/tunis/le-kram', 'Le Kram'),
#  ('https://www.med.tn/pharmacie/garde/tunis/el-ouerdia', 'El Ouerdia'),
#  ('https://www.med.tn/pharmacie/garde/tunis/el-manar-1', 'El Manar 1'),
#  ('https://www.med.tn/pharmacie/garde/tunis/les-berges-du-lac-2',
#   'Les Berges Du Lac 2'),
#  ('https://www.med.tn/pharmacie/garde/tunis/centre-urbain-nord',
#   'Centre Urbain Nord'),
#  ('https://www.med.tn/pharmacie/garde/tunis/jebel-jelloud', 'Jebel Jelloud')]

# %%
duo_quartier[0][0]
# Out:
# 'https://www.med.tn/pharmacie/garde/tunis/le-bardo'

# %%
for i in duo_quartier:
    print(i[1])
# Out:
# Le Bardo
# Sidi Hassine
# La Marsa
# El Hrairia
# Le Kram
# El Ouerdia
# El Manar 1
# Les Berges Du Lac 2
# Centre Urbain Nord
# Jebel Jelloud

# %% [markdown]
# ## Scraping link by link

# %%
from time import time
from time import sleep
from random import randint

# %%
start_time = time()
requests = 0

# %%
from requests import get

# %%
noms = []
pre_adresses = []
pre_coors = []
phones = []
quartiers = []

for i in duo_quartier:
    print(i[0])
    
    response = get(i[0])
    
    timer = randint(8,15)
    #pause de loop
    print(timer)
    sleep(timer)
    
    #Scraping the links
    soup = BeautifulSoup(response.text,'html.parser')
    
    results = soup.find_all('div',class_="searchResults-itemDoctor")
    
    for j in results:
        #Setting the neighborhood
        print(i[1])
        quartiers.append(i[1])
        
        
        # Scraping the names
        print(j.find('span',class_='practitioner-name').text)
        noms.append("Pharmacie "+(j.find('span',class_='practitioner-name').text).lower())
        
        # Scraping the adresses
        print((j.find('div',class_='practitioner-address').find('p').text).strip())
        pre_adresses.append((j.find('div',class_='practitioner-address').find('p').text).strip())
        
        # Scraping the phone numbers
        print(j.find('span',class_='view-tel').text)
        phones.append((j.find('span',class_='view-tel').text).replace('.',''))        
   
        # Scraping the coordinates 
        print(j.find('a',class_='btn').findNext('a')['href'])
        pre_coors.append(j.find('a',class_='btn').findNext('a')['href'])
                
    
    
    
    
    
print(" *** Done ***")
# Out:
# https://www.med.tn/pharmacie/garde/tunis/le-bardo
# 12
# Le Bardo
# MOHAMED TABRIZI M''BARKI
# 62,avenue Beyrem Ettounsi Le Bardo Tunis                                Tunisie
# +216.71.583.686
# https://www.google.com/maps?saddr&daddr=36.801422,10.132089
# Le Bardo
# HOUCINE ZOUAIDI
# Bloc 1 N 4    Bardo Center Le Bardo Tunis                                Tunisie
# +216.71.500.050
# https://www.google.com/maps?saddr&daddr=36.809376,10.137058
# Le Bardo
# IMEN MELLOULI EP. GORGI
# 2,Avenue Habib Bourguiba Le Bardo Tunis                                Tunisie
# +216.71.511.795
# https://www.google.com/maps?saddr&daddr=36.808273,10.137392
# Le Bardo
# NABILA HAMDANI EP. SKHIRI
# Avenue 20 Mars Cite Bouchoucha Le Bardo Tunis                                Tunisie
# +216.71.580.111
# https://www.google.com/maps?saddr&daddr=36.806458,10.138031
# https://www.med.tn/pharmacie/garde/tunis/sidi-hassine
# 8
# Sidi Hassine
# DALEL JERBI EP. JEMLI WAHIBA
# Sidi hessine rond point ben dahha Sidi Hassine Tunis                                Tunisie
# +216.71.935.652
# https://www.google.com/maps?saddr&daddr=36.78215,10.110553
# Sidi Hassine
# INSAF TAMBOURA EP. LATIL
# Avenue 4850 Sidi Hassine Tunis                                Tunisie
# +216.71.591.410
# https://www.google.com/maps?saddr&daddr=36.8008585,10.1295494
# Sidi Hassine
# ASSIA BEKDACHE
# Av DU 14 JANVIER TUNIS SIDI HASSINE Sidi Hassine Tunis                                Tunisie
# +216.71.934.000
# tel:+21671934000
# Sidi Hassine
# LATIFA BEN MANSOUR EP. HICHERI
# 131,Avenue Mustapha Khaznadar Sidi Hassine Tunis                                Tunisie
# +216.71.560.659
# https://www.google.com/maps?saddr&daddr=36.798992,10.155293
# https://www.med.tn/pharmacie/garde/tunis/la-marsa
# 10
# La Marsa
# LEILA BEN SLAMA EP. ZOUARI
# 60,avenue Taieb M'Hiri La Marsa Tunis                                Tunisie
# +216.72.225.420
# https://www.google.com/maps?saddr&daddr=36.889851,10.321507
# La Marsa
# HELLA ROKBI EP. BEN MAAMER
# 161 Avenue HEDI CHAKER La Marsa Tunis                                Tunisie
# +216.71.379.888
# https://www.google.com/maps?saddr&daddr=36.8829831,10.3083971
# La Marsa
# ZEINEB DJAIT EP. BARKET
# 12,rue Mohamed Ali LAHOUECHE La Marsa Tunis                                Tunisie
# +216.71.775.963
# https://www.google.com/maps?saddr&daddr=36.881344,10.321472
# La Marsa
# AIDA LOUZIR EP. BEN MESSAOUD
# C.Comm.Carrefour    Route de la Marsa La Marsa Tunis                                Tunisie
# +216.71.779.075
# https://www.google.com/maps?saddr&daddr=36.865108,10.294639
# https://www.med.tn/pharmacie/garde/tunis/el-hrairia
# 13
# El Hrairia
# BADRIA TRIKI EP. KSOURI
# 1,rue 4001 El Hrairia Tunis                                Tunisie
# +216.71.529.902
# https://www.google.com/maps?saddr&daddr=36.794469,10.130919
# El Hrairia
# HABIBA GRINA
# Rue 4128 N 116    EL HRAIRIA 4 El Hrairia Tunis                                Tunisie
# +216.71.528.631
# https://www.google.com/maps?saddr&daddr=36.798847,10.135237
# El Hrairia
# LILIA BEN MAHMOUD EP. BEN HAMZA
# Avenue El Hrairia El Hrairia Tunis                                Tunisie
# +216.71.529.777
# https://www.google.com/maps?saddr&daddr=36.788624,10.112468
# https://www.med.tn/pharmacie/garde/tunis/le-kram
# 9
# Le Kram
# RACHID BEL AJOUZA
# 274,Avenue Habib Bourguiba Le Kram Tunis                                Tunisie
# +216.71.275.139
# https://www.google.com/maps?saddr&daddr=36.835750119086,10.316834437892
# Le Kram
# ANIS BEN ABDALLAH
# 49,Avenue Farhat Hached kram Le Kram Tunis                                Tunisie
# +216.71.277.904
# https://www.google.com/maps?saddr&daddr=36.840939,10.311541
# https://www.med.tn/pharmacie/garde/tunis/el-ouerdia
# 12
# El Ouerdia
# FATMA BEN HAMIDA EP. HAFSIA
# 11, rue 10114 El Ouerdia Tunis                                Tunisie
# +216.71.492.035
# https://www.google.com/maps?saddr&daddr=36.7704552,10.1974609
# El Ouerdia
# JALEL ABDALLAH
# 23,Avenue Bellevue El Ouerdia Tunis                                Tunisie
# +216.71.399.214
# https://www.google.com/maps?saddr&daddr=36.780312,10.192693
# https://www.med.tn/pharmacie/garde/tunis/el-manar-1
# 9
# El Manar 1
# NEJIBA TLEMCANI EP. DJAIBI
# Immeuble Le Campus El Manar 1 Tunis                                Tunisie
# +216.71.874.463
# https://www.google.com/maps?saddr&daddr=36.835335,10.150388
# https://www.med.tn/pharmacie/garde/tunis/les-berges-du-lac-2
# 13
# Les Berges Du Lac 2
# SLIM FARAH
# Lac Médical Center CITE LES PINS LAC 2 Les Berges Du Lac 2 Tunis                                Tunisie
# +216.71.267.599
# https://www.google.com/maps?saddr&daddr=36.845491,10.2837878
# https://www.med.tn/pharmacie/garde/tunis/centre-urbain-nord
# 9
# Centre Urbain Nord
# NARJESS KAMMOUN
# Imm MALEK TUNIS CENTRE URBAIN NORD Centre Urbain Nord Tunis                                Tunisie
# +216.71.948.145
# https://www.google.com/maps?saddr&daddr=36.845158,10.197236
# https://www.med.tn/pharmacie/garde/tunis/jebel-jelloud
# 14
# Jebel Jelloud
# SONIA CHERIF
# 144, Rue 9042 TUNIS JEBEL JELLOUD Jebel Jelloud Tunis                                Tunisie
# +216.71.490.206
# tel:+21671490206
#  *** Done ***

# %% [markdown]
# ### cleaning up adresses

# %%
adresses = []
for i in pre_adresses:
    adresses.append(i.replace('Tunisie','').replace('  ','').lower())

# %% [markdown]
# ### cleaning up coordinates

# %%
coors = []
for i in pre_coors:
    eq = i.find('=')
    print(i[eq+1:])
    coors.append(i[eq+1:])
# Out:
# 36.801422,10.132089
# 36.809376,10.137058
# 36.808273,10.137392
# 36.806458,10.138031
# 36.78215,10.110553
# 36.8008585,10.1295494
# tel:+21671934000
# 36.798992,10.155293
# 36.889851,10.321507
# 36.8829831,10.3083971
# 36.881344,10.321472
# 36.865108,10.294639
# 36.794469,10.130919
# 36.798847,10.135237
# 36.788624,10.112468
# 36.835750119086,10.316834437892
# 36.840939,10.311541
# 36.7704552,10.1974609
# 36.780312,10.192693
# 36.835335,10.150388
# 36.845491,10.2837878
# 36.845158,10.197236
# tel:+21671490206

# %%
for i,j in enumerate(coors):
    if "tel" in coors[i]:
        print('yep')
        coors[i] = "NO COORDINATES"
# Out:
# yep
# yep

# %%
coors
# Out:
# ['36.801422,10.132089',
#  '36.809376,10.137058',
#  '36.808273,10.137392',
#  '36.806458,10.138031',
#  '36.78215,10.110553',
#  '36.8008585,10.1295494',
#  'NO COORDINATES',
#  '36.798992,10.155293',
#  '36.889851,10.321507',
#  '36.8829831,10.3083971',
#  '36.881344,10.321472',
#  '36.865108,10.294639',
#  '36.794469,10.130919',
#  '36.798847,10.135237',
#  '36.788624,10.112468',
#  '36.835750119086,10.316834437892',
#  '36.840939,10.311541',
#  '36.7704552,10.1974609',
#  '36.780312,10.192693',
#  '36.835335,10.150388',
#  '36.845491,10.2837878',
#  '36.845158,10.197236',
#  'NO COORDINATES']

# %% [markdown]
# ## Merging the data we got

# %%
garde = []
for i,j,k,l,m in zip(noms,quartiers,adresses,coors,phones):
    t = (i,j,k,l,m)
    garde.append(t)

# %%
garde
# Out:
# [("Pharmacie mohamed tabrizi m''barki",
#   'Le Bardo',
#   '62,avenue beyrem ettounsi le bardo tunis',
#   '36.801422,10.132089',
#   '+21671583686'),
#  ('Pharmacie houcine zouaidi',
#   'Le Bardo',
#   'bloc 1 n 4bardo center le bardo tunis',
#   '36.809376,10.137058',
#   '+21671500050'),
#  ('Pharmacie imen mellouli ep. gorgi',
#   'Le Bardo',
#   '2,avenue habib bourguiba le bardo tunis',
#   '36.808273,10.137392',
#   '+21671511795'),
#  ('Pharmacie nabila hamdani ep. skhiri',
#   'Le Bardo',
#   'avenue 20 mars cite bouchoucha le bardo tunis',
#   '36.806458,10.138031',
#   '+21671580111'),
#  ('Pharmacie dalel jerbi ep. jemli wahiba',
#   'Sidi Hassine',
#   'sidi hessine rond point ben dahha sidi hassine tunis',
#   '36.78215,10.110553',
#   '+21671935652'),
#  ('Pharmacie insaf tamboura ep. latil',
#   'Sidi Hassine',
#   'avenue 4850 sidi hassine tunis',
#   '36.8008585,10.1295494',
#   '+21671591410'),
#  ('Pharmacie assia bekdache',
#   'Sidi Hassine',
#   'av du 14 janvier tunis sidi hassine sidi hassine tunis',
#   'NO COORDINATES',
#   '+21671934000'),
#  ('Pharmacie latifa ben mansour ep. hicheri',
#   'Sidi Hassine',
#   '131,avenue mustapha khaznadar sidi hassine tunis',
#   '36.798992,10.155293',
#   '+21671560659'),
#  ('Pharmacie leila ben slama ep. zouari',
#   'La Marsa',
#   "60,avenue taieb m'hiri la marsa tunis",
#   '36.889851,10.321507',
#   '+21672225420'),
#  ('Pharmacie hella rokbi ep. ben maamer',
#   'La Marsa',
#   '161 avenue hedi chaker la marsa tunis',
#   '36.8829831,10.3083971',
#   '+21671379888'),
#  ('Pharmacie zeineb djait ep. barket',
#   'La Marsa',
#   '12,rue mohamed ali lahoueche la marsa tunis',
#   '36.881344,10.321472',
#   '+21671775963'),
#  ('Pharmacie aida louzir ep. ben messaoud',
#   'La Marsa',
#   'c.comm.carrefourroute de la marsa la marsa tunis',
#   '36.865108,10.294639',
#   '+21671779075'),
#  ('Pharmacie badria triki ep. ksouri',
#   'El Hrairia',
#   '1,rue 4001 el hrairia tunis',
#   '36.794469,10.130919',
#   '+21671529902'),
#  ('Pharmacie habiba grina',
#   'El Hrairia',
#   'rue 4128 n 116el hrairia 4 el hrairia tunis',
#   '36.798847,10.135237',
#   '+21671528631'),
#  ('Pharmacie lilia ben mahmoud ep. ben hamza',
#   'El Hrairia',
#   'avenue el hrairia el hrairia tunis',
#   '36.788624,10.112468',
#   '+21671529777'),
#  ('Pharmacie rachid bel ajouza',
#   'Le Kram',
#   '274,avenue habib bourguiba le kram tunis',
#   '36.835750119086,10.316834437892',
#   '+21671275139'),
#  ('Pharmacie anis ben abdallah',
#   'Le Kram',
#   '49,avenue farhat hached kram le kram tunis',
#   '36.840939,10.311541',
#   '+21671277904'),
#  ('Pharmacie fatma ben hamida ep. hafsia',
#   'El Ouerdia',
#   '11, rue 10114 el ouerdia tunis',
#   '36.7704552,10.1974609',
#   '+21671492035'),
#  ('Pharmacie jalel abdallah',
#   'El Ouerdia',
#   '23,avenue bellevue el ouerdia tunis',
#   '36.780312,10.192693',
#   '+21671399214'),
#  ('Pharmacie nejiba tlemcani ep. djaibi',
#   'El Manar 1',
#   'immeuble le campus el manar 1 tunis',
#   '36.835335,10.150388',
#   '+21671874463'),
#  ('Pharmacie slim farah',
#   'Les Berges Du Lac 2',
#   'lac médical center cite les pins lac 2 les berges du lac 2 tunis',
#   '36.845491,10.2837878',
#   '+21671267599'),
#  ('Pharmacie narjess kammoun',
#   'Centre Urbain Nord',
#   'imm malek tunis centre urbain nord centre urbain nord tunis',
#   '36.845158,10.197236',
#   '+21671948145'),
#  ('Pharmacie sonia cherif',
#   'Jebel Jelloud',
#   '144, rue 9042 tunis jebel jelloud jebel jelloud tunis',
#   'NO COORDINATES',
#   '+21671490206')]

# %% [markdown]
# ### Convert into a Pandas Object

# %%
import pandas as pd

# %%
df = pd.DataFrame(garde,columns=['nom','quartier','adresse','coordonnee','telephone'])

# %%
df
# Out:
#                                           nom             quartier  \
# 0          Pharmacie mohamed tabrizi m''barki             Le Bardo
# 1                   Pharmacie houcine zouaidi             Le Bardo
# 2           Pharmacie imen mellouli ep. gorgi             Le Bardo
# 3         Pharmacie nabila hamdani ep. skhiri             Le Bardo
# 4      Pharmacie dalel jerbi ep. jemli wahiba         Sidi Hassine
# 5          Pharmacie insaf tamboura ep. latil         Sidi Hassine
# 6                    Pharmacie assia bekdache         Sidi Hassine
# 7    Pharmacie latifa ben mansour ep. hicheri         Sidi Hassine
# 8        Pharmacie leila ben slama ep. zouari             La Marsa
# 9        Pharmacie hella rokbi ep. ben maamer             La Marsa
# 10          Pharmacie zeineb djait ep. barket             La Marsa
# 11     Pharmacie aida louzir ep. ben messaoud             La Marsa
# 12          Pharmacie badria triki ep. ksouri           El Hrairia
# 13                     Pharmacie habiba grina           El Hrairia
