# %% [markdown]
# # Combining the data of 2 datasets

# %%
import pandas as pd

# %%
df = pd.read_csv('pdg_rabat.csv',delimiter=';',index_col=0)

# %%
df.head(25)
# Out:
#                             pharmacie  \
# 0                Pharmacie  la Pinède
# 1              Pharmacie  La Reussite
# 2                 Pharmacie  La Rosee
# 3              Pharmacie  La Vitalité
# 4              Pharmacie  le Claridge
# 5               Pharmacie  le Dauphin
# 6            Pharmacie  les Almohades
# 7              Pharmacie  les Arcades
# 8             Pharmacie  les colonnes
# 9                 Pharmacie  Les Iris
# 10               Pharmacie  les Lilas
# 11  Pharmacie  les Ministères d'Agdal
# 12           Pharmacie  les Peupliers
# 13                   Pharmacie  Lotus
# 14                Pharmacie  Loubaris
# 15            Pharmacie  Louka Pharma
# 16                 Pharmacie  Lumière
# 17                 Pharmacie  Mabella
# 18                 Pharmacie  Marassa
# 19          Pharmacie  Marché de Gros
# 20          Pharmacie  av Mohammed VI
# 21            Pharmacie  Av. Goundafa
# 22                     Pharmacie  Aya
# ...

# %% [markdown]
# ## Dataset containing the neighborhoods

# %%
dq = pd.read_excel('q.xlsx')

# %%
dq.head(25)
# Out:
#     Unnamed: 0  Unnamed: 1                           pharmacie  \
# 0          NaN           0               Pharmacie  la PinÃ¨de
# 1          NaN           1              Pharmacie  La Reussite
# 2          NaN           2                 Pharmacie  La Rosee
# 3          NaN           3             Pharmacie  La VitalitÃ©
# 4          NaN           4              Pharmacie  le Claridge
# 5          NaN           5               Pharmacie  le Dauphin
# 6          NaN           6            Pharmacie  les Almohades
# 7          NaN           7              Pharmacie  les Arcades
# 8          NaN           8             Pharmacie  les colonnes
# 9          NaN           9                 Pharmacie  Les Iris
# 10         NaN          10                Pharmacie  les Lilas
# 11         NaN          11  Pharmacie  les MinistÃ¨res d'Agdal
# 12         NaN          12            Pharmacie  les Peupliers
# 13         NaN          13                    Pharmacie  Lotus
# ...

# %% [markdown]
# **Cleaning dataset**

# %%
dq.drop(['Unnamed: 0', 'Unnamed: 1'],axis=1)
# Out:
#                               pharmacie  \
# 0                 Pharmacie  la PinÃ¨de
# 1                Pharmacie  La Reussite
# 2                   Pharmacie  La Rosee
# 3               Pharmacie  La VitalitÃ©
# 4                Pharmacie  le Claridge
# 5                 Pharmacie  le Dauphin
# 6              Pharmacie  les Almohades
# 7                Pharmacie  les Arcades
# 8               Pharmacie  les colonnes
# 9                   Pharmacie  Les Iris
# 10                 Pharmacie  les Lilas
# 11   Pharmacie  les MinistÃ¨res d'Agdal
# 12             Pharmacie  les Peupliers
# 13                     Pharmacie  Lotus
# 14                  Pharmacie  Loubaris
# 15              Pharmacie  Louka Pharma
# 16                  Pharmacie  LumiÃ¨re
# 17                   Pharmacie  Mabella
# 18                   Pharmacie  Marassa
# 19           Pharmacie  MarchÃ© de Gros
# 20            Pharmacie  av Mohammed VI
# 21              Pharmacie  Av. Goundafa
# ...
