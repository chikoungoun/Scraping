# %% [markdown]
# # Combining  csv file contains the 300+ pharmacies from telecontact

# %%
import pandas as pd

# %%
ph1 = pd.read_csv('ph1.csv',delimiter=';',index_col=0)
ph2 = pd.read_csv('ph2.csv',delimiter=';',index_col=0)
ph3 = pd.read_csv('ph3.csv',delimiter=';',index_col=0)
ph4 = pd.read_csv('ph4.csv',delimiter=';',index_col=0)
ph5 = pd.read_csv('ph5.csv',delimiter=';',index_col=0)

# %%
frames = [ph1,ph2,ph3,ph4,ph5]
result = pd.concat(frames)

# %%
result
# Out:
#                                       pharmacie  \
# 0                          Pharmacie  la Pinède
# 1                        Pharmacie  La Reussite
# 2                           Pharmacie  La Rosee
# 3                        Pharmacie  La Vitalité
# 4                        Pharmacie  le Claridge
# 5                         Pharmacie  le Dauphin
# 6                      Pharmacie  les Almohades
# 7                        Pharmacie  les Arcades
# 8                       Pharmacie  les colonnes
# 9                           Pharmacie  Les Iris
# 10                         Pharmacie  les Lilas
# 11            Pharmacie  les Ministères d'Agdal
# 12                     Pharmacie  les Peupliers
# 13                             Pharmacie  Lotus
# 14                          Pharmacie  Loubaris
# 15                      Pharmacie  Louka Pharma
# 16                           Pharmacie  Lumière
# 17                           Pharmacie  Mabella
# ...

# %%
result.describe()
# Out:
#                        pharmacie  \
# count                       1324
# unique                       311
# top     Pharmacie  les Peupliers
# freq                           9
#
#                                                      lien     access  \
# count                                                1324       1324
# unique                                                311        299
# top     https://www.telecontact.ma/annonceur/pharmacie...  NO ACCESS
# freq                                                    9         63
#
#             coordonnee
# count             1324
# unique             271
# top     NO COORDINATES
# freq                63
