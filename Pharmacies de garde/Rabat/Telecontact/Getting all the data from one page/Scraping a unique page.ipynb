# %%
import requests

url = 'https://www.telecontact.ma/annonceur/pharmacie-warda-/3076398/rabat.php'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(response.text,'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Pharmacie Warda :  Maroc - Telecontact</title><meta content="Pharmacie Warda  rabat. Téléphone/Fax, Map : Pharmacie Warda 7, avenue Bir Kacem, Souissi.Quartier:  rabat. pharmacies Telecontact, Annuaire pages jaunes du maroc" lang="fr" name="Description" xml:lang="fr"/><meta content="Telecontact, annuaire pages jaunes maroc,Pharmacie Warda  , rabat. numero de telephone, numero de fax, adresse, plan d'acces, activite, " lang="fr" name="Keywords" xml:lang="fr"/> <link href="https://www.telecontact.ma/annonceur/pharmacie-warda-/3076398/rabat.php" rel="canonical"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <!-- core CSS -->
# <link href="/trouver/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="/trouver/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="/trouver/css/animate.min.css" rel="stylesheet"/>
# ...

# %% [markdown]
# ### Scraping the pharmacie name

# %%
name = soup.find('h1',id='lenom').text

# %%
name.strip()
# Out:
# 'Pharmacie Warda'

# %% [markdown]
# ### Scraping phone number

# %%
phone = soup.find('div',class_='letel').find('strong').text

# %%
phone
# Out:
# '05 37 65 99 77'

# %% [markdown]
# ### Scraping adresses

# %%
adress = soup.find('div',class_='col-md-3 col-xs-12 col-sm-6 no-margin').text

# %%
adress = adress.replace("\n","").replace("\t","").replace("Adresse","").replace('  ','')

# %%
adress
# Out:
# ' 7, bd Bir Kacem , Souissi RABAT'

# %% [markdown]
# ### Scraping coordinates

# %% [markdown]
# Coordinate scraping function

# %%
setview = s[deb:]
fin = setview.find(']')
setview_full =  setview[:fin+1]
    
#Take out the elements 
s_full = setview_full[setview_full.find('[')+1:setview_full.find(']')]

# %%
  
response = requests.get(url)
s = response.text

print("LatLng" in s)

#Isolate SetView
deb = s.find('LatLng')
print(deb)
LatLng = s[deb:]
fin = LatLng.find(')')
LatLng_full = LatLng[:fin+1]

s_full = LatLng_full[LatLng_full.find('(')+1:LatLng_full.find(')')]
# Out:
# True
# 67870

# %%
s_full
# Out:
# '34.00753797, -6.84787464'

# %%
lat,lng = s_full.split(',')

# %%
print(lat)
print(lng)
# Out:
# 34.00753797
#  -6.84787464
